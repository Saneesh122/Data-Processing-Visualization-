# %% [markdown]
# <a href="https://colab.research.google.com/github/Saneesh122/Data-Processing-Visualization-/blob/main/Proposal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Project proposal
#
# Sanish Shrestha
#
# Prof. Jacob, Nicholas C

# %% [markdown]
# **Topic support**-
#
# This proposal will tell us how the Amazon company was doing on the revenue over certain time period.

# %% [markdown]
# Down below is the chart of Amazon revenue over a year. This clearly shows how the company is doing in each quater over a year. As we can see that the company is growing significantly over a year time period.

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# This is the chart of amazon revenue over 5 years of period and as we can see the bar graph the companies revenue is going higher and higher in every quarter but looking at the yearly bar grap it tells us there were some time period when amazon revenue did not do better compared to previous quarters which tells us what year the company revenue did good and whent the company revenue did not perform very well.

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# The above picture is of a post that was posted on macrotrend website:-https://www.macrotrends.net/stocks/charts/AMZN/amazon/revenue which tells us how much amazon has grown over the period of 10 years both quaterly and yearly.

# %% [markdown]
# Learning from topic:-
#
# I would like to say that the data given by the bar chart completely makes us clear and easy to understand anything that we search about the company and helps to know the companies depth. It clearly shows us when the company had bad revenue compared to previous revenue results and when the company had the good revenure compared to the other revenues over a certain time period.
