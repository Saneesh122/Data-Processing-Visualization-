# %% [markdown]
# <a href="https://colab.research.google.com/github/Saneesh122/Data-Processing-Visualization-/blob/main/Initial_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Uploading data here**:-

# %%
import pandas as pa
import seaborn as sns
import matplotlib.pyplot as plt
df= pa.read_csv('https://raw.githubusercontent.com/Saneesh122/Data-Processing-Visualization-/main/data.csv')
df.head(20)
# Out:
#           Date  SP500  Dividend  Earnings  Consumer Price Index  \
# 0   1871-01-01   4.44      0.26      0.40                 12.46
# 1   1871-02-01   4.50      0.26      0.40                 12.84
# 2   1871-03-01   4.61      0.26      0.40                 13.03
# 3   1871-04-01   4.74      0.26      0.40                 12.56
# 4   1871-05-01   4.86      0.26      0.40                 12.27
# 5   1871-06-01   4.82      0.26      0.40                 12.08
# 6   1871-07-01   4.73      0.26      0.40                 12.08
# 7   1871-08-01   4.79      0.26      0.40                 11.89
# 8   1871-09-01   4.84      0.26      0.40                 12.18
# 9   1871-10-01   4.59      0.26      0.40                 12.37
# 10  1871-11-01   4.64      0.26      0.40                 12.37
# 11  1871-12-01   4.74      0.26      0.40                 12.65
# 12  1872-01-01   4.86      0.26      0.40                 12.65
# 13  1872-02-01   4.88      0.27      0.41                 12.65
# ...

# %% [markdown]
# **Initial Visualization**:-

# %%
import numpy as np 
import pandas as pa 
from scipy import stats 
import matplotlib.pyplot as plt 
import seaborn as sns 
import requests 
import pandas as pd 
from bs4 import BeautifulSoup 
import re

# %%
df1=df.groupby('SP500') 
df2=df1.first()
df2
# Out:
#                Date  Dividend  Earnings  Consumer Price Index  \
# SP500
# 2.73     1877-06-01      0.24      0.29                 10.09
# 2.85     1877-07-01      0.24      0.29                 10.18
# 2.94     1877-04-01      0.26      0.29                 10.47
# 3.05     1877-08-01      0.23      0.29                  9.80
# 3.17     1877-03-01      0.27      0.28                 10.18
# ...             ...       ...       ...                   ...
# 2642.19    4/1/2018       NaN       NaN                249.84
# 2664.34   12/1/2017     48.93    109.88                246.52
# 2702.77    3/1/2018     50.00       NaN                249.55
# 2705.16    2/1/2018     49.64       NaN                248.99
# 2789.80    1/1/2018     49.29       NaN                247.87
#
#          Long Interest Rate  Real Price  Real Dividend  Real Earnings   PE10
# SP500
# 2.73                   4.40       67.63           6.07           7.18    NaN
# ...

# %% [markdown]
# **Some cleaning of the datas down below**:-

# %%
df.columns
# Out:
# Index(['Date', 'SP500', 'Dividend', 'Earnings', 'Consumer Price Index',
#        'Long Interest Rate', 'Real Price', 'Real Dividend', 'Real Earnings',
#        'PE10'],
#       dtype='object')

# %%
cols = df.columns.map(lambda s: re.sub(r"[.\d[(.$M%\d)\]]","",s))
cols
# Out:
# Index(['Date', 'SP', 'Dividend', 'Earnings', 'Consumer Price Index',
#        'Long Interest Rate', 'Real Price', 'Real Dividend', 'Real Earnings',
#        'PE'],
#       dtype='object')

# %%
df.columns = df.columns.map(lambda s: re.sub(r"[.\d[(.$M%\d)\]]","",s))

# %%
df.columns
# Out:
# Index(['Date', 'SP', 'Dividend', 'Earnings', 'Consumer Price Index',
#        'Long Interest Rate', 'Real Price', 'Real Dividend', 'Real Earnings',
#        'PE'],
#       dtype='object')

# %%
cols1 = df.columns.map(lambda s: re.sub(r" ","",s))
cols1
# Out:
# Index(['Date', 'SP', 'Dividend', 'Earnings', 'ConsumerPriceIndex',
#        'LongInterestRate', 'RealPrice', 'RealDividend', 'RealEarnings', 'PE'],
#       dtype='object')

# %%
df.columns = df.columns.map(lambda s: re.sub(r" ","",s))

# %%
df.columns
# Out:
# Index(['Date', 'SP', 'Dividend', 'Earnings', 'ConsumerPriceIndex',
#        'LongInterestRate', 'RealPrice', 'RealDividend', 'RealEarnings', 'PE'],
#       dtype='object')

# %% [markdown]
# **Visualization in respect to dividend and earnings where in each earning the dividend goes higher and higher**:-

# %%
ax = sns.barplot(data = df, x = 'ConsumerPriceIndex', y= "RealDividend", ci= None)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 20)
ax.set_title('Bottom to Top')
plt.show()

# %% [markdown]
# Original link to the data:-
#
# https://datahub.io/core/s-and-p-500#resource-data
