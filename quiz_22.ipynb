# %% [markdown]
# <a href="https://colab.research.google.com/github/Saneesh122/Data-Processing-Visualization-/blob/main/quiz_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# quiz 22

# %% [markdown]
#  Head over to Oklahaoma Research Day. Spend some time looking at three posters that include statistical charts or graphs. Include links to each. Discuss the strengths and weaknesses of each. Do they display excellence or do they lie?

# %% [markdown]
# Here is the link to the presentation: https://symposium.foragerone.com/okrd22/presentations/37513

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# From what I see is- it is an brilliant work done here after collecting datas.
