# %% [markdown]
# <a href="https://colab.research.google.com/github/Saneesh122/Data-Processing-Visualization-/blob/main/Proposal_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Amazon revenue over the years**
#
# **Project Recent Visualization Final report**
#
# **Sanish Shrestha**
#
# **Dr.Nicholas Jacob**
#
# **CPSMA 4313**
#
# **Data Processing Visualization**

# %% [markdown]
# **The topic is properly motivated with reasons why it is timely and what you hope** **to show with your**
# **report**.:-

# %% [markdown]
# I have choosen amazon revenue as the topic to visualize because I have always been in the stock market for about 4 years now and I have seen a lots of chart and datas for different stock in the market.
#
# I choose amazon revenues over the years because it will give us the idea of what the stock and the company is doing over the years for the investment purpose and to trade the stock as well. This stock has done very good in over the years and it is doing great as of now too and I believe it will be doing great in coming years too but what I wanna show is if we take a look at the quarterly revenue it does good and some times it does bad comparing to other quaterly revenue. But in the overall it does great at the end. Amazon stock has been one of my favorite stock since the beginning through out my trading journey and I think it will be my favorite stock forever.
#
# The reason it timely is I will explain what the data is showing over the quarter, over a specific year, and over the past year. I will try to show what we can perdict or where the stock price is heading towards. I can be wrong but I will present the informantion based on what I see and think about the company amazon(AMZN).

# %% [markdown]
# **Three references of current articles that include data visulization**:-

# %% [markdown]
# **First reference**:-

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# The above data visualization is from the website:https://www.macrotrends.net/stocks/charts/AMZN/amazon/revenue which shows the performance of the amazon company in the year 2017. We can clearly see that quarterly performance of the stock fluctutes which means sometimes it performs better and some times it does not but when we look at the trailing 12 months we can see that the company is doing great compared at the end of the year. On the Y-axis is the revenue in billions which means 120= $120 billions. By looking at the end of the year amazon company is in the good shape by making a lot of money in every quarters regardless of how it performs in each quarter.

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# **Second reference**:-

# %% [markdown]
# The above visualization is from: https://finance.yahoo.com/quote/AMZN/financials?p=AMZN which is a website where you can search for any companies, go through their financials, revenue, news, datas of earnings, and all other information of a company. I chose the above visualization because I want to explain what can we learn by comparing both first and second visualization. In first we chose to visualize the data with in a year 2017 and saw the ups and downs of earnings quarterly but if we check yearly visulization the company is growing in a rapid way regardless of what it does in the quarter. If the company misses its EPS(Earnings Per Share) the price of the comapany tends to drop that is where people will look an oppurtunity to by the share in a cheaper price that it was before earning. So, for the conclusion I would say, by looking into the visualization above we can invest in amazon for the longer term for a better return in the future.

# %% [markdown]
# **Third reference**:-

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# The above visualization is from the website: https://www.insiderintelligence.com/insights/amazon-revenue/ which provides information about the source of income of a company and many other information of the company. In this visualization we just need to see the change in percentage which is colored in red and the sum amount of money made in a year which is the colored in black and the numbers are in billions. The above visualization helps us to know how much money is made by amazon with the help of retail ecommerce sales which is in percentage as per the visualization above.

# %% [markdown]
# **Similarities and differences of the visualization**:-

# %% [markdown]
# **Similarites**:-
#
# All the visualizations shows how the company is doing over the time period. The first one shows the company growth over the quarter, second one shows how the company is doing based on years, the third one shows where the money is flowing from. So all those three visualization is inter-connected in some ways.
#
# **Differences**:-
#
# All the visualizations have difference in graphics. The third once seems to be more vibrant compared to other two visualizations and first two shows the growth of the company but the third one shows how the company is growing.

# %% [markdown]
# **References**:-

# %% [markdown]
# https://finance.yahoo.com/quote/AMZN/history?p=AMZN
#
# https://finance.yahoo.com/quote/AMZN/financials?p=AMZN
#
# https://www.insiderintelligence.com/insights/amazon-revenue/
