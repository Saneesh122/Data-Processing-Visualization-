# %% [markdown]
# <a href="https://colab.research.google.com/github/Saneesh122/Data-Processing-Visualization-/blob/main/RecreatingMasters_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Processing Visualization**
#
# **Sanish Shrestha**
#
# **Recreate Master Final**
#
# **Dr. Nicholas Jacob**
#
# **CPSMA 4313**

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# **Link to the original visualiztion of the above**:-
#
# https://www.nytimes.com/2020/08/18/business/stock-market-record.html
