# %% [markdown]
# <a href="https://colab.research.google.com/github/Saneesh122/Data-Processing-Visualization-/blob/main/Project_proposal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Project proposal
#
# Sanish Shrestha
#
# Jacob,Nicholas C

# %% [markdown]
# Here, I am writing a proposal for my project and the proposal is about the performance of S&P 500 which is the index for 500 US companies combined and I have choosen this topic because it tells us the growth after the 2019 pandemic. Down below is the chart that I have pulled out from the link: https://www.cnbc.com/2021/12/30/stock-market-futures-open-to-close-news.html
# which shows how S&P 500 grew over a year after the pandemic. During the pandemic S&P 500 almost dropped nearly 34% and after the start of 2021 S&P 500 gain the momentum and rallied all the way up making all time high in December of 2021 which was the significant growth over a year.

# %% [markdown]
# Down below is the snapshot of S&P 500 chart in 2021 from Jan to Dec:-

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# Here is the link to the data set for S&P 500 which shows the open, close, high, low, & volume within 2021: https://seekingalpha.com/symbol/SP500/historical-price-quotes?gclid=Cj0KCQjw6pOTBhCTARIsAHF23fK4ESzk8tYC9YVqvq0UkGrLPcY9CiGt48fWNCTfXk-l7ApCMEwrJsEaAvMPEALw_wcB&internal_promotion=true&utm_campaign=15199871039&utm_medium=cpc&utm_source=google&utm_term=130394018078%5Eaud-850696509727%3Adsa-1432401538280%5E%5E559673290314%5E%5E%5Es

# %% [markdown]
# I would like to say it as a excellent visualization because we can clearly analyze and interpret how the S&P 500 performed over 1 year of time right after the pandemic.
